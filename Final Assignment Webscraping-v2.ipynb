# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/Images/SN_logo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1>Extracting Stock Data Using a Web Scraping</h1>

# %% [markdown]
# Not all stock data is available via the API in this assignment; you will use web-scraping to obtain financial data. You will be quizzed on your results.
#  You will extract and share historical data from a web page using the BeautifulSoup library.

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. Extracting data using BeautifulSoup
#
#     <ul>
#     <li> Download the web page Using Requests Library </li>
#     <li> Parse HTML on a web page using BeautifulSoup </li>
#     <li> Extract data and duild a data frame </li>
#
#     </ul>
#
# 2. Extracting data using pandas
# 3. Exercise
# <p>
#     Estimated Time Needed: <strong>30 min</strong></p>
# </div>
#
# <hr>

# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib 
# !pip install lxml
# !pip install plotly
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in d:\anaconda\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: bs4 in d:\anaconda\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from bs4) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\lib\site-packages (from beautifulsoup4->bs4) (4.12.1)
# Requirement already satisfied: html5lib in d:\anaconda\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in d:\anaconda\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: lxml in d:\anaconda\lib\site-packages (5.3.0)
# Requirement already satisfied: plotly in d:\anaconda\lib\site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in d:\anaconda\lib\site-packages (from plotly) (1.30.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from plotly) (23.0)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in d:\anaconda\lib\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in d:\anaconda\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\anaconda\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in d:\anaconda\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in d:\anaconda\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\anaconda\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\anaconda\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2024.12.14)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
# !pip install --upgrade yfinance
# !pip install --upgrade requests
# Out:
# Requirement already satisfied: yfinance in d:\anaconda\lib\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in d:\anaconda\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\anaconda\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in d:\anaconda\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in d:\anaconda\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\anaconda\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\anaconda\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2024.12.14)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests) (2024.12.14)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# In Python, you can ignore warnings using the warnings module. You can use the filterwarnings function to filter or ignore specific warning messages or categories.

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## Using Webscraping to Extract Stock Data Example

# %% [markdown]
# We will extract Netflix stock data [https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html).

# %% [markdown]
# <center>
#
# #### In this example, we are using yahoo finance website and looking to extract Netflix data.
#
# </center>
#     <br>
#
#   <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/Images/netflix.png"> </center>
#
# <center> Fig:- Table that we need to extract </center>

# %% [markdown]
# On the following web page we have a table with columns name (Date, Open, High, Low, close, adj close volume) out of which we must extract following columns
#
# * Date
#
# * Open
#
# * High
#
# * Low
#
# * Close
#
# * Volume

# %% [markdown]
# # Steps for extracting the data
# 1. Send an HTTP request to the web page using the requests library.
# 2. Parse the HTML content of the web page using BeautifulSoup.
# 3. Identify the HTML tags that contain the data you want to extract.
# 4. Use BeautifulSoup methods to extract the data from the HTML tags.
# 5. Print the extracted data

# %% [markdown]
# ### Step 1: Send an HTTP request to the web page

# %% [markdown]
# You will use the request library for sending an HTTP request to the web page.<br>

# %%
url = "https://finance.yahoo.com/quote/F/history/?guccounter=1&guce_referrer=aHR0cHM6Ly9sb2dpbi55YWhvby5jb20v&guce_referrer_sig=AQAAAEFNqdVKzhEgPiKXmLJHvtVT2eQ6Yp4zKiwVS0fdSxash9f8yzp9449wEHKZczbfnubST4yDzw4ci6daQrHm9OxwaHRun2xQk42TwTi7lpu4M_PhZ7G-wKQtGXz6IMy4NLJhYRRc6hOr1CPijKvb62xMNT5HDv-KSNP7aklfHDMM&frequency=1wk"

# %% [markdown]
# The requests.get() method takes a URL as its first argument, which specifies the location of the resource to be retrieved. In this case, the value of the url variable is passed as the argument to the requests.get() method, because you will store a web page URL in a url variable.
#
# You use the .text method for extracting the HTML content as a string in order to make it readable.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}
data = requests.get(url, headers=headers).text
print(data)
# Out:
# <!doctype html>
# <html lang="en-US" theme="auto" data-color-theme-enabled="true" data-color-scheme="auto" class="desktop neo-green dock-upscale">
#     <head>
#         <meta charset="utf-8" />
#         <meta name="oath:guce:consent-host" content="guce.yahoo.com" />
#         <link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous"><link rel="preconnect" href="//geo.yahoo.com"/><link rel="preconnect" href="//query1.finance.yahoo.com"/><link rel="preconnect" href="//query2.finance.yahoo.com"/><link rel="preconnect" href="//consent.cmp.oath.com"/><link rel="preload" href="/__rapidworker-1.2.js" as="worker"/><link rel="preconnect" href="https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.js"/><link rel="preconnect" href="https://cdn.jsdelivr.net/npm/protobufjs@7.1.2/dist/minimal/protobuf.min.js"/><script>window.finNeoPageStart = Date.now();</script><script>(function(){if(!window.YAHOO){window.YAHOO={}}; window.YAHOO.context={"consent":{"allowContentPersonalization":true,"allowCrossDeviceMapping":true,"allowFirstPartyAds":true,"allowSellPersonalInfo":true,"canEmbedThirdPartyContent":true,"canSell":true,"consentedVendors":["acast","brightcove","dailymotion","facebook","flourish","giphy","instagram","nbcuniversal","playbuzz","scribblelive","soundcloud","tiktok","vimeo","twitter","youtube","masque"]},"authed":"0","ynet":"0","ssl":"1","spdy":"0","ytee":"0","mode":"normal","tpConsent":true,"site":"finance","adblock":"0","bucket":"","colo":"ir2","device":"desktop","bot":"0","browser":"chrome","app":"unknown","ecma":"modern","environment":"prod","gdpr":false,"lang":"en-US","dir":"ltr","intl":"us","network":"mobile","os":"windows nt","partner":"none","region":"US","time":1742337352446,"tz":"Africa/Casablanca","usercountry":"MA","rmp":"0","webview":"0","feature":["disableInterstitialUpsells","disableServiceRewrite","disableBack2Classic","disableYPFTaxArticleDisclosure","enable1PVideoTranscript","enableAdRefresh20s","enableAnalystRatings","enableAPIRedisCaching","enableArticleCSN","enableChartbeat","enableChatSupport","enableCommunityToPremiumSubs","enableCommunityTrades","enableCompare","enableCompareConvertCurrency","enableConsentAndGTM","enableCrumbRefresh","enableCSN","enableCurrencyConverter","enableDarkMode","enableDockAddToFollowing","enableDockCondensedHeader","enableDockNeoOptoutLink","enableDockPortfolioControl","enableExperimentalDockModules","enableFollow","enableLazyQSP","enableLiveBlogStatus","enableLivePage","enableStreamingNowBar","enableLocalSpotIM","enableMarketsLeafHeatMap","enableMultiQuote","enableNeoAdvancedChart","enableNeoArticle","enableNeoAuthor","enableNeoBasicPFs","enableNeoGreen","enableNeoHouseCalcPage","enableNeoInvestmentIdea","enableNeoMortgageCalcPage","enableNeoPortfolioDetail","enableNeoQSPReportsLeaf","enableNeoResearchReport","enableNeoTopics","enablePersonalFinanceArticleReadMoreAlgo","enablePersonalFinanceNewsletterIntegration","enablePersonalFinanceZillowIntegration","enablePf2SubsSpotlight","enablePfLandingP2","enablePfPremium","enablePfStreaming","enablePinholeScreenshotOGForQuote","enablePlus","enablePortalStockStory","enableQSPChartEarnings","enableQSPChartNewShading","enableQSPChartRangeTooltips","enableQSPEarnings","enableQSPEarningsVsRev","enableQSPHistoryPlusDownload","enableQSPNavIcon","enableQuoteLookup","enableRecentQuotes","enableResearchHub","enableSECFiling","enableSigninBeforeCheckout","enableSmartAssetMsgA","enableStockStoryPfPage","enableStockStoryTimeToBuy","enableStreamOnlyNews","enableSubsFeatureBar","enableTradeNow","enableYPFArticleReadMoreAll","enableOnePortfolioBanner","enableVideoInHero","enableDockQuoteEventsDateRangeSelect","enablePfDetailDockCollapse","enableHoneyLinks","enableCompareFeatures","enableGenericHeatMap","enableQSPIndustryHeatmap","enableStatusBadge"],"isDebug":false,"isForScreenshot":false,"isWebview":false,"theme":"auto","pnrID":"","isError":false,"areAdsEnabled":true,"ccpa":{"warning":"","footerSequence":["terms_and_privacy","dashboard"],"links":{"dashboard":{"url":"https://guce.yahoo.com/privacy-dashboard?locale=en-US","label":"Privacy Dashboard","id":"privacy-link-dashboard"},"terms_and_privacy":{"multiurl":true,"label":"${terms_link}Terms${end_link} and ${privacy_link}Privacy Poli ...
#             function _nimbusSendEVLoadEvent() {
#                 if (_nimbusEvLoad._player){
#                     window.finNeoEVReady = Date.now();
#                     window.dispatchEvent(new CustomEvent('NIMBUS_EV_READY',{detail: {}}));
#                 }
#             }
#             function onNimbusEVPlayerReady(){_nimbusEvLoad._player = true;_nimbusSendEVLoadEvent();}</script><script type="module">if(!window.finWebCore){window.finWebCore=function r(e){const{isModern:t=!0,isDev:i=!1,lang:a=s,devAssets:o,prodAssets:r,crumb:n="",features:c=[],strings:d}=e;let f={};const m=a.substring(a.lastIndexOf("-")+1);return{crumb:n,lang:a,region:m,features:c,store:{},intl:m.toLowerCase(),strings:d,assets:i?o:r,addScriptTag(e,s,t){if(!e)return;const i=document.createElement("script");i.setAttribute("src",e),i.setAttribute("type","text/javascript"),"function"==typeof t&&(i.onload=()=>{t(!0)},i.onerror=()=>{t(!1)});for(const e in s)e&&Object.prototype.hasOwnProperty.call(s,e)&&void 0!==s[e]&&i.setAttribute(e,s[e]);document.body.appendChild(i)},addAsset(e,s={}){const{async:a=!0,defer:n,useModule:c=!1,callback:d}=s;if(f[e])return void("function"==typeof d&&d(!0));let m;if(m=i?o:r,!m||0===m.length)return;f[e]=!0;let u=m[0]&&m[0][e]&&m[0][e].mjs;c?(this.addScriptTag(u,{async:a,defer:n,type:"module"},d),m.length>1&&!i&&(u=m[1]&&m[1][e]&&m[1][e].js,this.addScriptTag(u,{async:a,defer:n,nomodule:!0},d))):(m.length>1&&!t&&(u=m[1]&&m[1][e]&&m[1][e].js),this.addScriptTag(u,{async:a,defer:n},d))},reset(){f={}}}}({isModern:true,isDev:false,lang:'en-US',features:[],devAssets:{},prodAssets:[{"_staticFinProtobuf":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.mjs"},"chart":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/chart.68695bc0cde81b6fd2c5.mjs"},"cryptoTrade":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/cryptoTrade.dcf34ddcb6166268ea19.mjs"},"finBankrateMortgageOffers":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finBankrateMortgageOffers.664a78dd057b52ca6292.mjs"},"finBarChart":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finBarChart.538f8a340c2cb6354b75.mjs"},"finGaugeChart":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finGaugeChart.fa1d27882fc12800746c.mjs"},"finHorizontalBarChart":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finHorizontalBarChart.3759f974570a40144429.mjs"},"finIcon":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finIcon.303dcbfc0a8c9e028f3e.mjs"},"finPlaidLink":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finPlaidLink.6584da6f7d5fc1edc4f7.mjs"},"finVizChart":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finVizChart.02a27bab264c8f050d5b.mjs"},"finYodlee":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/finYodlee.991ce7779f400c5305e1.mjs"},"importantDates":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/importantDates.9549c05d775935965234.mjs"},"marketSummary":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/marketSummary.ab701f613b4c97d5c74d.mjs"},"marketTime":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/marketTime.4b7f9356fd30261da5b2.mjs"},"navigation":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/navigation.26b467366246597f7472.mjs"},"portfolio":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/portfolio.63493b39ef80da733a7d.mjs"},"quoteSummary":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/quoteSummary.b1698f44b3b4a94b8b58.mjs"},"sparkLine":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/sparkLine.be4a748c75a1f617d549.mjs"},"streamer":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/streamer.248f993752a5b05fef83.mjs"},"ticker":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/ticker.5577058bafc1670a8665.mjs"},"xrayStocks":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/xrayStocks.ac6db3456e234015de83.mjs"},"":{"mjs":["https://s.yimg.com/uc/finance/webcore/js/portfolio.worker.df0761c07d30081fe88f.worker.mjs","https://s.yimg.com/uc/finance/webcore/js/streamer.worker.4db981fe5b4e331576b3.worker.mjs"]}},{"_staticFinProtobuf":{"js":"https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.js"},"chart":{"js":"https://s.yimg.com/uc/finance/webcore/js/chart.f646bb756945529b9afc.js"},"cryptoTrade":{"js":"https://s.yimg.com/uc/finance/webcore/js/cryptoTrade.dadf4921de0cc362780b.js"},"finBankrateMort ...
# 		<link href="../../../assets/_app/immutable/assets/2.C1JxrDLM.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PageProgressBar.BdiKnjd9.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/money.Cy0iVZOL.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Assets.DeMvfHuh.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/virtual_pwa-register.CKy0VdX8.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/ErrorMsg.CmzKsgiD.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Debug.BfmLJeTl.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Button.D47IMSwb.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/AccordionItem.Cku646hS.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Link.N50nO-bC.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Switch.BaMlRiYx.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Follow.agUa80w0.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/file_download.CHlKp2dt.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Tooltip.BodCepnd.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Header.BvCA0Mhu.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Typography.CeR4PxAH.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Dialogv2.kvClFfq8.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/24.vnlt25oh.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/AdGroup.BDGq8O-f.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Dock.DH3PLw7_.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/EventCalendarPreview.CD7glI99.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Lazy.B9y26vJt.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Spinner.DBQ4b_Oq.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/TickerSearch.CMJmje8A.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/AddToFollowing.CdzFv5ZV.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/MenuSurface.BjmZ0Ig-.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Dialog.Ch6G-Ji-.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/loadSECFilingDetails.CfnaMg_z.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Logo.DRMdLZx-.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PositionDeleteMessage.B-8pT6wm.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Image.BjjiB67D.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SignedOutVariantA.BHe2xtGG.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SignedOutVariantB.CwCcKdia.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/182.ClaEeBJW.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/monetization_on.Bv2RAPeL.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Footer.up8GcRs_.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Toast.U1m0D3h1.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/QuoteExchange.BCjAfcMG.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/QuotePrice.2FxreZEX.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Streamer.BucjdyxZ.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/QuoteTitle.CFASGB_1.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/NavBar.H5gl3KtW.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/149._yFy_4XO.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PrivateCompanyPartnerAttribution.C3lPLz_M.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/TickerCarousel.BKkdq0p7.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Card.CG4iZvyO.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Carousel.8E3lOV4L.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/CarouselButtons.dmN8w8Wj.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SectionHeader.B9ETuNQk.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Ticker.TP6ss69s.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/postUtils.DIRi4Cnr.css" rel="stylesheet"><title>Ford Motor Company (F) Stock Historical Prices &amp; Data - Yahoo Finance</title><!-- HEAD_svelte-1s46gf5_START --><!-- HTML_TAG_START --><link rel="manifest" href="/manifest.json"><!-- HTML_TAG_END --><!-- HEAD_svelte-1s46gf5_END --><!-- HEAD_svelte-1qdjli6_START --><!-- HTML_TAG_START --><script id="nimbus-benji-config" type="application/json">{"setting":{"refresh":{"duration":20,"requireUserAction":false,"limit":30,"tabFocus":{"outOfFocusDuration":3},"sameSizeRefresh":true,"reserved":{"duration":60}},"lazyLoad":false,"tracking":{"performance":true,"metrics":true},"taboolaSetting":{"pageType":"category","publisherId":"yahooweb-network"},"consent":{"allowOnlyLimitedAds":false,"allowOnlyNonPersonalizedAds":false},"userInfo":{"age":0,"gender":""}},"feature":{"enableAdCollapse":true,"enableAdStacking":true,"enableNewPremiumAdLogic":true},"positions":{"sda-E2E":{"id":"sda-E2E","path":"/22888152279/us/yfin/quote/dt/us_yfin_quote_dt_top_center","region":"index","size":[[3,1],[970,250],[728,90]],"kvs":{"loc":"top_center"},"customSizeConfig":{"Horizon":true}}},"i13n":{"colo":"ir2","lang":"en-US","mrkt":"us","navtype":"server","site":"finance","ver":"nimbus","theme":"auto","abk":"0","auth_state":"signed_out","partner":"none","pct":"qsp","pg_name":"history","milestone":"","pl1":"us_market","pl2":"NYQ","pstcat":"equities","pt":"utility","rvt":"F","ticker":"F","spaceid":"95993639","consent":{"allowContentPersonalization":true,"allowCrossDeviceMapping":true,"allowFirstPartyAds":true,"allowSellPersonalInfo":true,"canEmbedThirdPartyContent":true,"canSell":true,"consentedVendors":["acast","brightcove","dailymotion","facebook","flourish","giphy","instagram","nbcuniversal","playbuzz","scribblelive","soundcloud","tiktok","vimeo","twitter","youtube","masque"]},"authed":"0","ynet":"0","ssl":"1","spdy":"0","ytee":"0","mode":"normal","tpConsent":true,"adblock":"0","bucket":"","device":"desktop","bot":"0","browser":"chrome","app":"unknown","ecma":"modern","environment":"prod","gdpr":false,"dir":"ltr","intl":"us","network":"mobile","os":"windows nt","region":"US","time":1742337352446,"tz":"Africa/Casablanca","usercountry":"MA","rmp":"0","webview":"0","feature":["disableInterstitialUpsells","disableServiceRewrite","disableBack2Classic","disableYPFTaxArticleDisclosure","enable1PVideoTranscript","enableAdRefresh20s","enableAnalystRatings","enableAPIRedisCaching","enableArticleCSN","enableChartbeat","enableChatSupport","enableCommunityToPremiumSubs","enableCommunityTrades","enableCompare","enableCompareConvertCurrency","enableConsentAndGTM","enableCrumbRefresh","enableCSN","enableCurrencyConverter","enableDarkMode","enableDockAddToFollowing","enableDockCondensedHeader","enableDockNeoOptoutLink","enableDockPortfolioControl","enableExperimentalDockModules","enableFollow","enableLazyQSP","enableLiveBlogStatus","enableLivePage","enableStreamingNowBar","enableLocalSpotIM","enableMarketsLeafHeatMap","enableMultiQuote","enableNeoAdvancedChart","enableNeoArticle","enableNeoAuthor","enableNeoBasicPFs","enableNeoGreen","enableNeoHouseCalcPage","enableNeoInvestmentIdea","enableNeoMortgageCalcPage","enableNeoPortfolioDetail","enableNeoQSPReportsLeaf","enableNeoResearchReport","enableNeoTopics","enablePersonalFinanceArticleReadMoreAlgo","enablePersonalFinanceNewsletterIntegration","enablePersonalFinanceZillowIntegration","enablePf2SubsSpotlight","enablePfLandingP2","enablePfPremium","enablePfStreaming","enablePinholeScreenshotOGForQuote","enablePlus","enablePortalStockStory","enableQSPChartEarnings","enableQSPChartNewShading","enableQSPChartRangeTooltips","enableQSPEarnings","enableQSPEarningsVsRev","enableQSPHistoryPlusDownload","enableQSPNavIcon","enableQuoteLookup","enableRecentQuotes","enableResearchHub","enableSECFiling","enableSigninBeforeCheckout","enableSmartAssetMsgA","enableStockStoryPfPage","enableStockStoryTimeToBuy","enableStreamOnlyNews","enableSubsFeatur ...
# </script>
#     </head>
#
#     <body id="atomic">
#         <div id="sda-E2E" class="sdaContainer tw-flex tw-justify-center hideOnPrint"></div>
#         <div id="svelte">  <!-- HTML_TAG_START --><script type="module">if (!window._nimbus){window._nimbus={appState:{}};}window._nimbus.appState.debug={"headers":{},"liveConfig":{},"perf":[],"start":0,"content":{"items":[],"sections":[]}};</script><!-- HTML_TAG_END -->   <div id="app-err-banner" style="display: none;"><div class="no-data sz-large   yf-1lk1oh4   bold" role="alert" data-testid="error-msg"><div aria-hidden="true" class="icon fin-icon tertiary-icn sz-xx-large  yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M11 15h2v2h-2zm0-8h2v6h-2zm.99-5C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2M12 20c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8"/></svg><!-- HTML_TAG_END --></div> <p class="tertiary yf-1lk1oh4 centerText">Oops, something went wrong</p> </div></div> <!-- HTML_TAG_START --><script type="application/json" id="fin-trending-tickers">[{"fullExchangeName":"NasdaqGS","symbol":"NVDA","gmtOffSetMilliseconds":-14400000,"language":"en-US","regularMarketTime":{"raw":1742328000,"fmt":"4:00PM EDT"},"regularMarketChangePercent":{"raw":-3.4301002,"fmt":"-3.43%"},"quoteType":"EQUITY","typeDisp":"Equity","companyLogoUrl":"https://s.yimg.com/lb/brands/150x150_nvidia.png","tradeable":false,"regularMarketPreviousClose":{"raw":119.53,"fmt":"119.53"},"exchangeTimezoneName":"America/New_York","regularMarketChange":{"raw":-4.0999985,"fmt":"-4.10"},"trendingScore":{"raw":68.94445057617885,"fmt":"6,894.45%"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":917015400000,"exchangeTimezoneShortName":"EDT","logoUrl":"https://s.yimg.com/lb/brands/150x150_nvidia.png","hasPrePostMarketData":true,"customPriceAlertConfidence":"HIGH","regularMarketPrice":{"raw":115.43,"fmt":"115.43"},"marketState":"POST","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NMS","shortName":"NVIDIA Corporation","region":"US","triggerable":true,"longName":"NVIDIA Corporation"},{"fullExchangeName":"NasdaqGS","symbol":"META","gmtOffSetMilliseconds":-14400000,"language":"en-US","regularMarketTime":{"raw":1742328001,"fmt":"4:00PM EDT"},"regularMarketChangePercent":{"raw":-3.726242,"fmt":"-3.73%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":604.9,"fmt":"604.90"},"exchangeTimezoneName":"America/New_York","regularMarketChange":{"raw":-22.54004,"fmt":"-22.54"},"trendingScore":{"raw":50.32866764766021,"fmt":"5,032.87%"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":1337347800000,"exchangeTimezoneShortName":"EDT","hasPrePostMarketData":true,"customPriceAlertConfidence":"HIGH","regularMarketPrice":{"raw":582.36,"fmt":"582.36"},"marketState":"POST","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NMS","shortName":"Meta Platforms, Inc.","region":"US","triggerable":true,"longName":"Meta Platforms, Inc."},{"fullExchangeName":"NasdaqGS","symbol":"SRPT","gmtOffSetMilliseconds":-14400000,"language":"en-US","regularMarketTime":{"raw":1742328000,"fmt":"4:00PM EDT"},"regularMarketChangePercent":{"raw":-27.439564,"fmt":"-27.44%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":101.35,"fmt":"101.35"},"exchangeTimezoneName":"America/New_York","regularMarketChange":{"raw":-27.809998,"fmt":"-27.81"},"trendingScore":{"raw":35.752853649055425,"fmt":"3,575.29%"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":865431000000,"exchangeTimezoneShortName":"EDT","hasPrePostMarketData":true,"customPriceAlertConfidence":"HIGH","regularMarketPrice":{"raw":73.54,"fmt":"73.54"},"marketState":"POST","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NMS","shortName":"Sarepta Therapeutics, Inc.","region":"US","triggerable":true,"longName":"Sarepta Therapeutics, Inc."},{"fullExcha ...
# /*! Copyright 2017 Yahoo Holdings, Inc. All rights reserved. */
# template{display:none}._yb_3pvg03{font-family:"Helvetica Neue",Helvetica,Tahoma,Geneva,Arial,sans-serif;font-family:var(--yb-default-font);font-weight:400;font-weight:var(--yb-font-regular);font-stretch:normal;direction:ltr;display:block;box-sizing:border-box;text-align:start;-webkit-font-smoothing:antialiased;z-index:1000;overflow-anchor:none}.ybar-ytheme-crunch._yb_3pvg03,.ybar-ytheme-fuji2._yb_3pvg03{font-family:"YahooSans VF",YahooSans,"Yahoo Sans","Helvetica Neue",Helvetica,Arial,sans-serif;font-family:var(--yb-fuji2-font)}html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch{text-shadow:none;text-shadow:var(--yb-text-shadow)}html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch button,html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch ._yb_1imywey,html[data-color-theme-enabled][data-color-scheme=transparent] #ybar-nav-placement{text-shadow:none}html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch svg{filter:var(--yb-icon-filter)}html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch button svg,html[data-color-theme-enabled][data-color-scheme=transparent] .ybar-ytheme-crunch ._yb_1imywey svg,html[data-color-theme-enabled][data-color-scheme=transparent] #ybar-nav-placement svg{filter:none}#ybar._yb_1i21p8a{margin:0 auto}._yb_3pvg03 ._yb_1532fab{display:flex;flex-direction:column}.ybar-ytheme-crunch #ybar-inner-wrap{background:#fff;background:var(--yb-background-color)}._yb_16knoa6{display:flex;justify-content:center}._yb_16dm8g4{display:flex;justify-content:flex-start;align-items:center;width:100%;min-width:0;max-width:1920px;box-sizing:border-box;transition:margin .2s ease-out,opacity .15s linear .2s;opacity:1}.ybar-ytheme-crunch ._yb_16dm8g4{max-width:calc(100% - 32px);max-width:var(--uh-max-width, calc(100% - 32px))}.typing .ybar-ytheme-crunch ._yb_1532fab{transition:margin .2s ease-out}.ybar-ytheme-fuji2 ._yb_16dm8g4{max-width:1340px;padding:0 20px;transition:margin .2s ease-out,opacity .15s linear .2s,padding .4s}.ybar-property-sports._yb_rdn1yj #ybar-navigation{max-width:100%;padding:0}.ybar-sticky #ybar._yb_rdn1yj #ybar-inner-wrap{left:0}.ybar-ytheme-fuji2._yb_17bm25z ._yb_16dm8g4,.ybar-ytheme-fuji2._yb_17bm25z ._yb_lrldux ._yb_16dm8g4{padding:0;margin:0}.ybar-ytheme-fuji2._yb_17bm25z ._yb_16knoa6._yb_1o6z0bs,.ybar-ytheme-fuji2._yb_17bm25z ._yb_16knoa6._yb_lrldux{padding:0 20px;transition:padding .4s}@media screen and (min-width:1020px){.ybar-ytheme-fuji2 ._yb_16dm8g4{padding:0 40px}.ybar-ytheme-fuji2._yb_17bm25z ._yb_16knoa6._yb_1o6z0bs,.ybar-ytheme-fuji2._yb_17bm25z ._yb_16knoa6._yb_lrldux{padding:0 40px}}.ybar-ytheme-fuji2._yb_1aba10i ._yb_16dm8g4{padding:0;max-width:100%}.ybar-ytheme-fuji2._yb_1e93rlf._yb_17bm25z ._yb_16dm8g4{max-width:1264px;min-width:0}._yb_1l1j82q ._yb_16dm8g4,.ybar-ytheme-fuji2._yb_1knbg1m ._yb_1l1j82q ._yb_16dm8g4,.ybar-ytheme-fuji2._yb_17bm25z ._yb_1l1j82q ._yb_16dm8g4{padding:0;position:relative;display:none}.ybar-ytheme-fuji2 ._yb_1l1j82q ._yb_16dm8g4{display:flex}.ybar-ytheme-fuji2.ybar-property-mail.fuji2-dialpad ._yb_1l1j82q{display:none}._yb_dpa6zd{background:#232a31;background:var(--yb-topnav-bg);flex:1}.ybar-dark ._yb_dpa6zd{background:#464e56;background:var(--yb-charcoal)}.ybar-dark ._yb_b3y5kj ._yb_dpa6zd{background-color:#7e1fff;background-color:var(--yb-hulk-pants)}.ybar-ytheme-fuji2 ._yb_1l1j82q{overflow:hidden}@media screen and (max-width:1340px){.ybar-ytheme-fuji2 ._yb_1l1j82q{width:100%;min-width:1032px}.ybar-ytheme-fuji2 ._yb_dpa6zd{display:none}}._yb_1wpi12z{min-width:0;padding:0;height:84px}._yb_1u6ktze ._yb_1wpi12z,._yb_1e1scn3 ._yb_1wpi12z,._yb_1i21p8a ._yb_1wpi12z,._yb_165ua6g ._yb_1wpi12z,._yb_1tbqop3 ._yb_1wpi12z,._yb_jgm9i5 ._yb_1wpi12z,._yb_103prsx ._yb_1wpi12z{padding:0 64px 0 50px}._yb_1ju6fyw._yb_16knoa6._yb_1imywey{padding:0 16px;margin-bottom:8px;justify-content:center;width:auto}._yb_1knbg1m ._yb_1ju6fyw._yb_16knoa6._ ...
# /*! rtl:ignore */
# ._yb_18j2b5c{overflow:hidden;display:inline-block;font-size:12px;font-weight:500;color:#020e65;text-align:center;text-decoration:none;vertical-align:middle}._yb_f8x4wm{background-image:linear-gradient(207deg,#ff03ab,#ff0200);border-radius:100px;border-width:0;height:18px;left:11.5px;opacity:.71;padding-left:6px;padding-right:5px;position:absolute;top:-5px;visibility:hidden;width:auto}._yb_f8x4wm._yb_ngvbhz{visibility:visible}._yb_1bxy8uy{visibility:hidden;width:auto}._yb_f8x4wm._yb_1bxy8uy{visibility:visible}.ybar-ytheme-crunch ._yb_f8x4wm{background:#6001d2;background:var(--yb-grape-jelly);left:25px;height:15px;width:16px;top:0;opacity:1;padding:0}.ybar-ytheme-crunch ._yb_f8x4wm._yb_rmfbat{left:22px}.ybar-ytheme-crunch:not(.ybar-uh3-desktop) ._yb_1eqezty{padding:0 4px}.ybar-ytheme-fuji2 ._yb_17ob6zj ._yb_f8x4wm,.ybar-ytheme-fuji2 ._yb_17ob6zj._yb_aszg8c ._yb_f8x4wm{opacity:1}._yb_13p0emy ._yb_f8x4wm{background-color:#f0162f;border:0;border-radius:9px;color:#fff;color:var(--yb-white);font-size:11px;height:initial;left:initial;line-height:18px;padding:0 8px;right:-9px;top:-6px;vertical-align:middle;width:initial}._yb_f8x4wm ._yb_1ees5bt{color:#fff;display:block;font-size:12px;font-weight:600;line-height:18px;margin-top:0;text-align:center}.ybar-ytheme-crunch ._yb_f8x4wm ._yb_1ees5bt{line-height:15px;font-size:10px}._yb_13p0emy ._yb_f8x4wm ._yb_1ees5bt{display:inline}._yb_1u4qwlc{font-family:"YahooSans VF",YahooSans,"Yahoo Sans","Helvetica Neue",Helvetica,Arial,sans-serif;font-family:var(--yb-fuji2-font);font-weight:600;font-size:12px;max-width:80px;margin-left:8px;vertical-align:middle;color:#232a31;color:var(--yb-mail-icon-text);text-align:left;display:inline-block}.ybar-dark ._yb_1u4qwlc{color:#fff;color:var(--yb-white)}@media only screen and (max-width:1024px){._yb_1u4qwlc{display:none}}._yb_1ol4tnf{white-space:nowrap;overflow:hidden;text-overflow:ellipsis}._yb_z599m{font-weight:700}._yb_zf4hrj{text-align:center;padding:20px 24px}._yb_1ozblj6{color:#0078ff;color:var(--yb-mail-signin-link);text-decoration:none}._yb_1ozblj6:visited{color:#324fe1}._yb_eq8uj5{font-weight:400;font-weight:var(--yb-font-regular);width:300px;right:0;opacity:0;transition:visibility 0s linear .4s,max-height 0s linear .4s,opacity .15s linear .4s;top:33px}._yb_2sxe12{background-color:rgb(35 42 49/80%);border-radius:8px;box-shadow:0 0 1px rgba(0 0 0/10%),0 4px 8px rgba(0 0 0/10%);font-weight:400;font-weight:var(--yb-font-regular);right:-12px;opacity:0;padding:8px 14px;transition:visibility 0s linear .4s;top:42px;pointer-events:none;width:30px;visibility:hidden}.ybar-ytheme-crunch ._yb_a4qtsl ._yb_2sxe12{min-width:195px;right:-69px;margin-top:8px;padding:8px 12px}.ybar-ytheme-crunch ._yb_a4qtsl ._yb_cv1t97{min-width:inherit;justify-content:center;margin:0}.ybar-ytheme-crunch ._yb_773whp._yb_a4qtsl._yb_ngvbhz ._yb_2sxe12 ._yb_cv1t97._yb_a4qtsl,.ybar-ytheme-crunch ._yb_773whp._yb_a4qtsl ._yb_2sxe12 ._yb_cv1t97._yb_a4qtsl._yb_1hcm2wb{visibility:hidden;display:none}.ybar-ytheme-crunch ._yb_a4qtsl._yb_ngvbhz ._yb_2sxe12 ._yb_a4qtsl._yb_cv1t97._yb_1hcm2wb{visibility:visible;display:flex}._yb_cv1t97{color:#fff;color:var(--yb-white);margin-left:2px}._yb_773whp:hover ._yb_2sxe12,._yb_1qdhr6j:focus+._yb_2sxe12{visibility:visible;opacity:1;padding-top:8px}.ybar-dark .ybar-ytheme-crunch ._yb_2sxe12,.ybar-dark .ybar-ytheme-crunch ._yb_cv1t97{background-color:rgba(255 255 255/80%);color:#232a31;color:var(--yb-batcave)}._yb_h52qp3._yb_eq8uj5:after{border-bottom-color:#f5f8fa;border-bottom-color:var(--yb-marshmallow)}._yb_vbjbcc._yb_eq8uj5:before,._yb_vbjbcc._yb_eq8uj5:after{border-bottom-color:#6001d2;border-bottom-color:var(--yb-grape-jelly)}.ybar-variant-att ._yb_eq8uj5._yb_1u2ntrv{width:200px}._yb_eq8uj5:before,._yb_eq8uj5:after{right:35px}._yb_20hw4m{max-height:calc(100vh - 110px);overflow-y:auto}._yb_20hw4m>:first-child{border-top-left-radius:4px;border-top-right-radius:4px}._yb_4edytb{padding:12px 20px 20px;position:relative;display:block;text-decoration:none;bord ...
#         {"assist_billboard_v2":true,"enable_search_ui":true,"highlight_searchassist":true,"overlay_class":"midnight60","scrollThreshold":4}
#     </script>  <div id="ybar-inner-wrap" class="_yb_1532fab "><div class="_yb_1hdyes"></div>     <div class="_yb_16knoa6 _yb_1o6z0bs _yb_lw9sxh"><div class="_yb_16dm8g4 _yb_1wpi12z"> <div class="_yb_pycosv"><div class="_yb_1889u5l"><button id="_yb_sidenav-btn" class="_yb_1o24fo6 rapid-noclick-resp" aria-label="Y! Sites" aria-expanded="false"><svg width="20" height="20" viewBox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M17.5001 5.83342H2.50008C2.03966 5.83342 1.66675 5.46008 1.66675 5.00008C1.66675 4.54008 2.03966 4.16675 2.50008 4.16675H17.5001C17.9601 4.16675 18.3334 4.54008 18.3334 5.00008C18.3334 5.46008 17.9601 5.83342 17.5001 5.83342ZM17.5001 11.2501H2.50008C2.03966 11.2501 1.66675 10.8767 1.66675 10.4167C1.66675 9.95633 2.03966 9.58341 2.50008 9.58341H17.5001C17.9601 9.58341 18.3334 9.95633 18.3334 10.4167C18.3334 10.8767 17.9601 11.2501 17.5001 11.2501ZM2.50008 16.6667H17.5001C17.9601 16.6667 18.3334 16.2934 18.3334 15.8334C18.3334 15.373 17.9601 15.0001 17.5001 15.0001H2.50008C2.03966 15.0001 1.66675 15.373 1.66675 15.8334C1.66675 16.2934 2.03966 16.6667 2.50008 16.6667Z" fill="#232A31"></path></svg></button><div class="_yb_1xdo81p _yb_39nirn   "> <div class="_yb_10tc2ab _yb_2os0je"><div class="_yb_11twl8a"><div class="_yb_1h4hyh0 _yb_2os0je"><div class="_yb_1c3suha"></div><button class="_yb_19t0qsy _yb_2os0je rapid-noclick-resp" aria-label="Close button"><svg width="20" height="20" viewBox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M9.99935 8.82328L5.58435 4.40828C5.26518 4.08911 4.73602 4.08661 4.41102 4.41161C4.08435 4.73911 4.08518 5.26161 4.40852 5.58494L8.82268 9.99994L4.40852 14.4141C4.08852 14.7341 4.08685 15.2624 4.41102 15.5874C4.73852 15.9149 5.26185 15.9141 5.58435 15.5908L9.99935 11.1758L14.4143 15.5908C14.7335 15.9108 15.2627 15.9124 15.5877 15.5874C15.9143 15.2608 15.9135 14.7374 15.5902 14.4141L11.176 9.99994L15.5902 5.58494C15.9102 5.26494 15.9118 4.73661 15.5877 4.41161C15.2602 4.08494 14.7368 4.08578 14.4143 4.40828L9.99935 8.82328Z" fill="#232A31"></path></svg></button></div>    <section class="_yb_j8lnua _yb_15ux1a _yb_2os0je"><h3 class="_yb_1fddb99 _yb_2os0je" tabindex="0"> <div class="_yb_sjj2wl _yb_14ba0ze _yb_2os0je"><a href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;" class="_yb_1rqdw2g" tabindex="-1">News</a></div><div class="_yb_z06951 _yb_pm8s81 _yb_2os0je" tabindex="0"><svg width="20" height="20" viewBox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M10.0011 10.6612L5.91234 6.57241C5.59699 6.25789 5.06949 6.25294 4.74754 6.57489C4.42228 6.90014 4.42393 7.41939 4.74506 7.73969L10.0011 12.9966L15.2588 7.73804C15.5742 7.42269 15.5791 6.89519 15.2564 6.57324C14.9319 6.24881 14.4127 6.24963 14.0916 6.57076L10.0011 10.6612Z" fill="#232A31"></path></svg></div></h3><ul class="_yb_ko5ref _yb_2os0je"> <li class="_yb_1yr9rsg   _yb_2os0je"> <a class="_yb_1v0ieaw" href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;news&#x2F;" data-ylk="slk:Today&#39;s news;elm:navcat;pkgt:side-nav;subsec:navrail;itc:0">Today&#39;s news</a>   </li>  <li class="_yb_1yr9rsg   _yb_2os0je"> <a class="_yb_1v0ieaw" href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;news&#x2F;us&#x2F;" data-ylk="slk:US;elm:navcat;pkgt:side-nav;subsec:navrail;itc:0">US</a>   </li>  <li class="_yb_1yr9rsg   _yb_2os0je"> <a class="_yb_1v0ieaw" href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;news&#x2F;politics&#x2F;" data-ylk="slk:Politics;elm:navcat;pkgt:side-nav;subsec:navrail;itc:0">Politics</a>   </li>  <li class="_yb_1yr9rsg   _yb_2os0je"> <a class="_yb_1v0ieaw" href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;news&#x2F;world&#x2F;" data-ylk="slk:World;elm:navcat;pkgt:side-nav;subsec:navrail;itc:0">World</a>   </li>  <li class="_yb_1yr9rsg  _yb_15f1pmd _yb_2os0je"> <a class="_yb_1v0ieaw" href="https:&#x2F;&#x2F;www.yahoo.com&#x2F;tech&#x2F;" data-ylk="slk:Tech;elm:navcat;pkgt:side-nav;subsec:navrail;itc:0">Tech</a>    <button class="_yb_z06951 _yb_ggdyb5 rapid-no ...
#                     win._ybar_runtime_config = win._ybar_runtime_config || {};
#                     Object.keys(cfg).forEach(function (key) {
#                         win._ybar_runtime_config[key] = cfg[key];
#                     });
#                 })(window, {"bucketConfig":{"assist_billboard_v2":true,"enable_search_ui":true,"highlight_searchassist":true,"overlay_class":"midnight60","scrollThreshold":4},"bucketNames":["ybar-enable-uh3-profile","ybar-shift-more-menu","ybar-show-notification","ybar-inline-logo-images","ybar-l1-highlight-customization","ybar-uh3-v1","ybar-enable-display-setting","ybar-shift-more-menu"],"componentCount":0,"device":"desktop","features":{"use_uh3_profile":true,"shift_more_menu":true,"show_notification":true,"use_inline_images":true,"l1_highlight_customization":true,"assist_billboard_v2":true,"avatarConfig":{"useAlphatar":true},"enable_search_ui":true,"login_icon_bg":true,"saMtestid":"35716=SAUHSearchBillboardsV2Test","search_cta_magnify":false,"show_mail_label":true,"suppress_topnavigation":true,"uh3_legacy_finance":false,"use_profile_character":true,"use_uh3_desktop_layout":true,"use_uh3_mail_v3":true,"voice_search":true,"show_display_setting":true},"i18n":{"root":{"PROPERTY_NAME":"Yahoo Finance","SEARCH_TOOLTIP_WEB":"Search the web","BACK":"Back","LITE_UPGRADE_PROMPT_MESSAGE":"Some parts of this page are not supported on your current browser version. Please upgrade to a recent browser version.","MAIL_ARIA_LINK":"Check your mail, {count} messages, link","NOTIF_ONBOARD_UPSELL_CLOSE":"Not now","NOTIF_ONBOARD_UPSELL_CTA":"Turn On","NOTIF_ONBOARD_UPSELL_SUBTITLE":"Keep up with the best stories in News, Sports, Finance, Entertainment and more!","NOTIF_ONBOARD_UPSELL_TITLE":"Get news push notification","SEARCH_TOOLTIP_VOICE":"Search by voice"}},"locale":"en-US","mailVariantLogos":{},"property":"finance","ytheme":"crunch"}); $_mod_ybar && $_mod_ybar.ready();</script><!-- HTML_TAG_END --> </div></header>  <section class="theme-dialog-wrapper yf-1bt0dri"><dialog class="no-bb  yf-1tpag22" role="dialog" aria-label="Appearance Selector"> </dialog> </section>  <main class="layoutContainer yf-cfn520" id="nimbus-app" tabindex="-1"><section class="mainContainer yf-cfn520"> <section class="mainContent yf-cfn520"><aside class="left yf-cfn520 stickyNavbar" aria-label="Left navigation"><section class="container yf-1adstsn" data-testid="quote-nav-bar"> <nav aria-label="F navigation" class="l1 yf-emp91w vertical"><ul class="nav-list tw-pt-[--space-3] md:tw-pt-[--space-1] yf-emp91w" role="menubar" aria-label="F navigation menubar"> <li role="none" class="yf-emp91w"><a category="summary" href="/quote/F/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:summary;milestonelink:" class="item   yf-emp91w" title="Summary"> <span class="ellipsis yf-emp91w">Summary </span>   </a> </li> <li role="none" class="yf-emp91w"><a category="news" href="/quote/F/news/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:news;milestonelink:" class="item   yf-emp91w" title="News"> <span class="ellipsis yf-emp91w">News </span>   </a> </li> <li role="none" class="yf-emp91w"><a category="chart" href="/quote/F/chart/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:chart;milestonelink:" class="item   yf-emp91w" title="Chart"> <span class="ellipsis yf-emp91w">Chart </span>   </a> </li> <li role="none" class="yf-emp91w"><a category="community" href="/quote/F/community/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:community;milestonelink:" class="item   yf-emp91w" title="Conversations"> <span class="ellipsis yf-emp91w">Conversations </span>   </a> </li> <li role="none" class="yf-emp91w"><a category="key-statistics" href="/quote/F/key-statistics/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:key-statistics;milestonelink:" class="item   yf-emp91w" title="Statistics"> <span class="ellipsis yf-emp91w">Statistics </span>   </a> </li> <li role="none" class="yf-emp91w"><a category="history" href="/quote/F/history/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:0;sec:qsp-fin-navbar;slk:history;milestonelink:" class="item  selected yf-emp91 ...
#         --logo-height: 25.5px;
#         --logo-width: 182px;
#         --logo-color: ;
#     ">  </div>  </a> <div class="copyright-wrapper yf-131dft8"><div>Copyright © 2025 Yahoo. All rights reserved.</div></div> <div class="social-links yf-131dft8"><a class="loud-link fin-size-small     yf-1xqzjha" data-ylk="elm:follow;elmt:logo;itc:0;sec:footer;slk:twitter" href="https://twitter.com/YahooFinance" aria-label="Follow on Twitter" title="Follow on Twitter" rel="noopener noreferrer" target="_blank"><div aria-hidden="true" class="icon fin-icon primary-icn sz-xx-large  yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M14.881 17.183h1.49L9.512 7.58H8.02z"/><path fill-rule="evenodd" d="M12 24c6.627 0 12-5.373 12-12S18.627 0 12 0 0 5.373 0 12s5.373 12 12 12m5.342-17.135-4.095 4.658 4.453 6.342h-3.275l-3-4.27-3.755 4.27H6.7l4.295-4.884L6.7 6.865h3.276l2.84 4.044 3.555-4.044z" clip-rule="evenodd"/></svg><!-- HTML_TAG_END --></div>   </a><a class="loud-link fin-size-small     yf-1xqzjha" data-ylk="elm:follow;elmt:logo;itc:0;sec:footer;slk:facebook" href="https://facebook.com/yahoofinance" aria-label="Follow on Facebook" title="Follow on Facebook" rel="noopener noreferrer" target="_blank"><div aria-hidden="true" class="icon fin-icon primary-icn sz-xx-large  yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" data-name="Layer 1" viewBox="0 0 24 24"><path d="M24 12c0-6.63-5.37-12-12-12S0 5.37 0 12c0 5.99 4.39 10.95 10.12 11.85v-8.39H7.07v-3.47h3.05V9.35c0-3.01 1.79-4.67 4.53-4.67 1.31 0 2.69.23 2.69.23v2.95h-1.51c-1.49 0-1.96.93-1.96 1.87v2.25h3.33l-.53 3.47h-2.8v8.39c5.74-.9 10.12-5.86 10.12-11.85Z"/></svg><!-- HTML_TAG_END --></div>   </a><a class="loud-link fin-size-small     yf-1xqzjha" data-ylk="elm:follow;elmt:logo;itc:0;sec:footer;slk:linkedin" href="https://www.linkedin.com/company/yahoo-finance" aria-label="Follow on LinkedIn" title="Follow on LinkedIn" rel="noopener noreferrer" target="_blank"><div aria-hidden="true" class="icon fin-icon primary-icn sz-xx-large  yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M12 0C5.372 0 0 5.372 0 12s5.372 12 12 12 12-5.372 12-12S18.628 0 12 0M8.644 17.02h-2.34V9.534h2.34zM7.41 8.597h-.019c-.848 0-1.397-.572-1.397-1.299 0-.74.567-1.298 1.43-1.298.862 0 1.392.558 1.41 1.298.006.722-.543 1.299-1.424 1.299M18 17.02h-2.653v-3.872c0-1.012-.413-1.706-1.327-1.706-.698 0-1.087.469-1.265.919-.066.16-.057.384-.057.614v4.045h-2.63s.034-6.862 0-7.486h2.63v1.177c.155-.516.994-1.247 2.335-1.247 1.664 0 2.967 1.078 2.967 3.394z"/></svg><!-- HTML_TAG_END --></div>   </a></div></div> <div class="trending yf-131dft8"><div class="colHeading yf-131dft8">POPULAR QUOTES</div> <a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/%5EDJI/">Dow Jones   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/SPY/">S&amp;P 500   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/%5EGDAXI/">DAX Index   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/NVDA/">Nvidia   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/TSLA/">Tesla   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/quote/DJT/">DJT   </a><a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:qte;elmt:link;itc:0;sec:footer" href="https://finance.yahoo.com/topic/tariffs/">Tariffs   </a></div> <div class="explore-more yf-131dft8"><div class="colHeading yf-131dft8">EXPLORE MORE</div> <a class="subtle-link fin-size-small     yf-1xqzjha" data-ylk="elm:hdln;elmt:link;itc:0;sec:footer" href="https: ...
#
#         --dock-sticky-top: 0px;
#         --dock-upscaled-width: 21.5625rem;
#     " aria-label="Dock" role="dialog" aria-modal="true"><div class="container yf-x6ev64"><div class="container-wrapper yf-x6ev64"><div class="header yf-x6ev64"><section class="dock-header yf-1mcu4dc condensed"> <div id="header-quote-lookup" tabindex="-1" class="yf-1mcu4dc"><div class="autoc-quote  formContainer yf-12kwijd" data-id="fin-autocomplete" data-testid="dock-srch"><form data-finsrch="quote" role="search" class="dock-srch yf-12kwijd"><div aria-hidden="true" class="icon fin-icon tertiary-icn sz-x-large tw-absolute !tw-inline-flex tw-top-0 tw-bottom-0 tw-m-[auto 0] tw-left-3 yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M15.5 14h-.79l-.28-.27A6.47 6.47 0 0 0 16 9.5 6.5 6.5 0 1 0 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14"/></svg><!-- HTML_TAG_END --></div>  <input aria-label="Quote Lookup" class="finsrch-inpt bg-dark inpt-placeholder-secondary  yf-12kwijd rounded bordered" type="text" aria-autocomplete="both" aria-haspopup="false" autocapitalize="off" autocomplete="off" autocorrect="off" placeholder="Quote Lookup" value=""> <div class="finsrch-rslt finsrch-custom-rst finsrch-show-recomlst yf-12kwijd finsrch-show-ftr"></div></form> </div></div> <div class="dock-action yf-1mcu4dc"><button class="icon2-btn fin-size-large edit subtle-dock-btn rounded   yf-1bk9lim" data-ylk="elm:itm;elmt:btn;itc:1;sec:dock" aria-label="Customize Your Dock"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-large  yf-z7spfk"><!-- HTML_TAG_START --><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M19.43 12.98c.04-.32.07-.64.07-.98s-.03-.66-.07-.98l2.11-1.65c.19-.15.24-.42.12-.64l-2-3.46a.5.5 0 0 0-.61-.22l-2.49 1c-.52-.4-1.08-.73-1.69-.98l-.38-2.65A.49.49 0 0 0 14 2h-4c-.25 0-.46.18-.49.42l-.38 2.65c-.61.25-1.17.59-1.69.98l-2.49-1a.6.6 0 0 0-.18-.03c-.17 0-.34.09-.43.25l-2 3.46c-.13.22-.07.49.12.64l2.11 1.65c-.04.32-.07.65-.07.98s.03.66.07.98l-2.11 1.65c-.19.15-.24.42-.12.64l2 3.46a.5.5 0 0 0 .61.22l2.49-1c.52.4 1.08.73 1.69.98l.38 2.65c.03.24.24.42.49.42h4c.25 0 .46-.18.49-.42l.38-2.65c.61-.25 1.17-.59 1.69-.98l2.49 1q.09.03.18.03c.17 0 .34-.09.43-.25l2-3.46c.12-.22.07-.49-.12-.64zm-1.98-1.71c.04.31.05.52.05.73s-.02.43-.05.73l-.14 1.13.89.7 1.08.84-.7 1.21-1.27-.51-1.04-.42-.9.68c-.43.32-.84.56-1.25.73l-1.06.43-.16 1.13-.2 1.35h-1.4l-.19-1.35-.16-1.13-1.06-.43c-.43-.18-.83-.41-1.23-.71l-.91-.7-1.06.43-1.27.51-.7-1.21 1.08-.84.89-.7-.14-1.13c-.03-.31-.05-.54-.05-.74s.02-.43.05-.73l.14-1.13-.89-.7-1.08-.84.7-1.21 1.27.51 1.04.42.9-.68c.43-.32.84-.56 1.25-.73l1.06-.43.16-1.13.2-1.35h1.39l.19 1.35.16 1.13 1.06.43c.43.18.83.41 1.23.71l.91.7 1.06-.43 1.27-.51.7 1.21-1.07.85-.89.7zM12 8c-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4-1.79-4-4-4m0 6c-1.1 0-2-.9-2-2s.9-2 2-2 2 .9 2 2-.9 2-2 2"/></svg><!-- HTML_TAG_END --></div> </button></div> </section></div> <div class="body yf-x6ev64">  <ul>   <li data-index="0" data-id="marketSummary" class="dock-item
#                                   dockRevealTarget dockRevealTarget-0
#
# ...
# 			<script type="application/json" data-sveltekit-fetched data-url="https://query1.finance.yahoo.com/v10/finance/quoteSummary/F?formatted=true&amp;modules=price%2CsummaryDetail%2CpageViews%2CfinancialsTemplate%2CquoteUnadjustedPerformanceOverview%2CcorporateActions&amp;lang=en-US&amp;region=US&amp;crumb=.KkWHAdvEEL" data-ttl="1">{"status":200,"statusText":"OK","headers":{},"body":"{\"quoteSummary\":{\"result\":[{\"summaryDetail\":{\"maxAge\":1,\"priceHint\":{\"raw\":2,\"fmt\":\"2\",\"longFmt\":\"2\"},\"previousClose\":{\"raw\":9.92,\"fmt\":\"9.92\"},\"open\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"dayLow\":{\"raw\":9.88,\"fmt\":\"9.88\"},\"dayHigh\":{\"raw\":10.04,\"fmt\":\"10.04\"},\"regularMarketPreviousClose\":{\"raw\":9.92,\"fmt\":\"9.92\"},\"regularMarketOpen\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"regularMarketDayLow\":{\"raw\":9.88,\"fmt\":\"9.88\"},\"regularMarketDayHigh\":{\"raw\":10.04,\"fmt\":\"10.04\"},\"dividendRate\":{\"raw\":0.75,\"fmt\":\"0.75\"},\"dividendYield\":{\"raw\":0.0756,\"fmt\":\"7.56%\"},\"exDividendDate\":{\"raw\":1739836800,\"fmt\":\"2025-02-18\"},\"payoutRatio\":{\"raw\":0.53419995,\"fmt\":\"53.42%\"},\"fiveYearAvgDividendYield\":{\"raw\":5.76,\"fmt\":\"5.76\"},\"beta\":{\"raw\":1.607,\"fmt\":\"1.61\"},\"trailingPE\":{\"raw\":6.8150682,\"fmt\":\"6.82\"},\"forwardPE\":{\"raw\":5.6857142,\"fmt\":\"5.69\"},\"volume\":{\"raw\":97348528,\"fmt\":\"97.35M\",\"longFmt\":\"97,348,528\"},\"regularMarketVolume\":{\"raw\":97348528,\"fmt\":\"97.35M\",\"longFmt\":\"97,348,528\"},\"averageVolume\":{\"raw\":87043443,\"fmt\":\"87.04M\",\"longFmt\":\"87,043,443\"},\"averageVolume10days\":{\"raw\":144752260,\"fmt\":\"144.75M\",\"longFmt\":\"144,752,260\"},\"averageDailyVolume10Day\":{\"raw\":144752260,\"fmt\":\"144.75M\",\"longFmt\":\"144,752,260\"},\"bid\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"ask\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"bidSize\":{\"raw\":36200,\"fmt\":\"36.2k\",\"longFmt\":\"36,200\"},\"askSize\":{\"raw\":41800,\"fmt\":\"41.8k\",\"longFmt\":\"41,800\"},\"marketCap\":{\"raw\":39436328960,\"fmt\":\"39.44B\",\"longFmt\":\"39,436,328,960\"},\"yield\":{},\"ytdReturn\":{},\"qtdReturn\":{},\"totalAssets\":{},\"expireDate\":{},\"strikePrice\":{},\"openInterest\":{},\"fiftyTwoWeekLow\":{\"raw\":9.06,\"fmt\":\"9.06\"},\"fiftyTwoWeekHigh\":{\"raw\":14.85,\"fmt\":\"14.85\"},\"priceToSalesTrailing12Months\":{\"raw\":0.21317856,\"fmt\":\"0.21\"},\"fiftyDayAverage\":{\"raw\":9.7084,\"fmt\":\"9.71\"},\"twoHundredDayAverage\":{\"raw\":10.8251,\"fmt\":\"10.83\"},\"trailingAnnualDividendRate\":{\"raw\":0.6,\"fmt\":\"0.60\"},\"trailingAnnualDividendYield\":{\"raw\":0.060483873,\"fmt\":\"6.05%\"},\"navPrice\":{},\"currency\":\"USD\",\"fromCurrency\":null,\"toCurrency\":null,\"lastMarket\":null,\"coinMarketCapLink\":null,\"volume24Hr\":{},\"volumeAllCurrencies\":{},\"circulatingSupply\":{},\"algorithm\":null,\"maxSupply\":{},\"startDate\":{},\"tradeable\":false},\"pageViews\":{\"shortTermTrend\":\"DOWN\",\"midTermTrend\":\"UP\",\"longTermTrend\":\"UP\",\"maxAge\":1},\"price\":{\"maxAge\":1,\"preMarketChangePercent\":{\"raw\":0.0030241702,\"fmt\":\"0.30%\"},\"preMarketChange\":{\"raw\":0.0299997,\"fmt\":\"0.03\"},\"preMarketTime\":1742304587,\"preMarketPrice\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"preMarketSource\":\"FREE_REALTIME\",\"postMarketChangePercent\":{\"raw\":-0.0010853676,\"fmt\":\"-0.11%\"},\"postMarketChange\":{\"raw\":-0.010799408,\"fmt\":\"-0.01\"},\"postMarketTime\":1742337334,\"postMarketPrice\":{\"raw\":9.9392,\"fmt\":\"9.94\"},\"postMarketSource\":\"FREE_REALTIME\",\"regularMarketChangePercent\":{\"raw\":0.0030241702,\"fmt\":\"0.30%\"},\"regularMarketChange\":{\"raw\":0.0299997,\"fmt\":\"0.03\"},\"regularMarketTime\":1742328002,\"priceHint\":{\"raw\":2,\"fmt\":\"2\",\"longFmt\":\"2\"},\"regularMarketPrice\":{\"raw\":9.95,\"fmt\":\"9.95\"},\"regularMarketDayHigh\":{\"raw\":10.04,\"fmt\":\"10.04\"},\"regularMarketDayLow\":{\"raw\":9.88,\"fmt\":\"9.88\"},\"regularMarketVolume\":{\"raw\":97348528,\"fmt\":\"97.35M\",\"longFmt\" ...
# 			<script type="application/json" data-sveltekit-fetched data-url="/xhr/stock-recommender?symbol=F&amp;lang=en-US&amp;region=US" data-ttl="14400">{"status":200,"statusText":"OK","headers":{},"body":"{\"pathId\":\"/document/v1/entity/entity/docid/ticker:F\",\"id\":\"id:entity:entity::ticker:F\",\"fields\":{\"related_tickers_ts\":1742286621,\"related_tickers\":[\"GM\",\"RIVN\",\"LCID\",\"NIO\",\"STLA\",\"XPEV\",\"TSLA\",\"TM\",\"LI\",\"BYDDY\"],\"id\":\"ticker:F\",\"entity_type\":\"ticker\"}}"}</script>
# 			<script type="application/json" data-sveltekit-fetched data-url="https://query1.finance.yahoo.com/v7/finance/quote?fields=marketCap%2CmorningstarIndustry%2ClogoUrl%2ClongName%2CregularMarketPrice%2CregularMarketChange%2CregularMarketChangePercent%2CshortName&amp;formatted=true&amp;imgHeights=50&amp;imgLabels=logoUrl&amp;imgWidths=50&amp;symbols=GM%2CRIVN%2CLCID%2CNIO%2CSTLA%2CXPEV%2CTSLA%2CTM%2CLI%2CBYDDY%2CF&amp;lang=en-US&amp;region=US&amp;crumb=.KkWHAdvEEL" data-ttl="1">{"status":200,"statusText":"OK","headers":{},"body":"{\"quoteResponse\":{\"result\":[{\"fullExchangeName\":\"NYSE\",\"symbol\":\"GM\",\"gmtOffSetMilliseconds\":-14400000,\"industry\":\"Auto Manufacturers\",\"language\":\"en-US\",\"regularMarketTime\":{\"raw\":1742328002,\"fmt\":\"4:00PM EDT\"},\"regularMarketChangePercent\":{\"raw\":-0.673473,\"fmt\":\"-0.67%\"},\"quoteType\":\"EQUITY\",\"typeDisp\":\"Equity\",\"tradeable\":false,\"currency\":\"USD\",\"sharesOutstanding\":{\"raw\":995001984,\"fmt\":\"995.002M\",\"longFmt\":\"995,001,984\"},\"regularMarketPreviousClose\":{\"raw\":49.0,\"fmt\":\"49.00\"},\"morningstarIndustry\":\"Auto Manufacturers\",\"exchangeTimezoneName\":\"America/New_York\",\"marketCap\":{\"raw\":48426745856,\"fmt\":\"48.427B\",\"longFmt\":\"48,426,745,856\"},\"regularMarketChange\":{\"raw\":-0.330002,\"fmt\":\"-0.33\"},\"cryptoTradeable\":false,\"exchangeDataDelayedBy\":0,\"firstTradeDateMilliseconds\":1290090600000,\"exchangeTimezoneShortName\":\"EDT\",\"hasPrePostMarketData\":true,\"marketState\":\"POST\",\"regularMarketPrice\":{\"raw\":48.67,\"fmt\":\"48.67\"},\"customPriceAlertConfidence\":\"HIGH\",\"market\":\"us_market\",\"quoteSourceName\":\"Delayed Quote\",\"priceHint\":2,\"exchange\":\"NYQ\",\"sourceInterval\":15,\"shortName\":\"General Motors Company\",\"region\":\"US\",\"triggerable\":true,\"longName\":\"General Motors Company\"},{\"fullExchangeName\":\"NasdaqGS\",\"symbol\":\"RIVN\",\"gmtOffSetMilliseconds\":-14400000,\"industry\":\"Auto Manufacturers\",\"language\":\"en-US\",\"regularMarketTime\":{\"raw\":1742328000,\"fmt\":\"4:00PM EDT\"},\"regularMarketChangePercent\":{\"raw\":1.6333878,\"fmt\":\"1.63%\"},\"quoteType\":\"EQUITY\",\"typeDisp\":\"Equity\",\"tradeable\":false,\"currency\":\"USD\",\"sharesOutstanding\":{\"raw\":1122889984,\"fmt\":\"1.123B\",\"longFmt\":\"1,122,889,984\"},\"regularMarketPreviousClose\":{\"raw\":11.02,\"fmt\":\"11.02\"},\"morningstarIndustry\":\"Auto Manufacturers\",\"exchangeTimezoneName\":\"America/New_York\",\"marketCap\":{\"raw\":12663952384,\"fmt\":\"12.664B\",\"longFmt\":\"12,663,952,384\"},\"regularMarketChange\":{\"raw\":0.17999935,\"fmt\":\"0.18\"},\"cryptoTradeable\":false,\"exchangeDataDelayedBy\":0,\"firstTradeDateMilliseconds\":1636554600000,\"exchangeTimezoneShortName\":\"EDT\",\"hasPrePostMarketData\":true,\"marketState\":\"POST\",\"regularMarketPrice\":{\"raw\":11.2,\"fmt\":\"11.20\"},\"customPriceAlertConfidence\":\"HIGH\",\"market\":\"us_market\",\"quoteSourceName\":\"Delayed Quote\",\"priceHint\":2,\"exchange\":\"NMS\",\"sourceInterval\":15,\"shortName\":\"Rivian Automotive, Inc.\",\"region\":\"US\",\"triggerable\":true,\"longName\":\"Rivian Automotive, Inc.\"},{\"fullExchangeName\":\"NasdaqGS\",\"symbol\":\"LCID\",\"gmtOffSetMilliseconds\":-14400000,\"industry\":\"Auto Manufacturers\",\"language\":\"en-US\",\"regularMarketTime\":{\"raw\":1742328001,\"fmt\":\"4:00PM EDT\"},\"regularMarketChangePercent\":{\"raw\":8.796288,\"fmt\":\"8.80%\"},\"quoteType\":\"EQUITY\",\"typeDisp\":\"Equity\",\"tradeable\":false,\"currency\":\"USD\",\"sharesOutstanding\":{\"raw\":3031500032,\"fmt\":\"3.032B\",\"longFmt\":\"3,031,500,032\"},\"regularMarketPreviousClose\":{\"raw\":2.16,\"fmt\":\"2.1600\"},\"morningstarIndustry\":\"Auto Manufacturers\",\"exchangeTimezoneName\":\"America/New_York\",\"marketCap\":{\"raw\":7124024832,\"fmt\":\"7.124B\",\"longFmt\":\"7,124,024,832\"},\"regularMarketChange\":{\"raw\":0.18999982,\"fmt\":\"0.1900\"},\"cryptoTradeable\":false,\"exchangeDataDelayedBy\":0,\" ...
# 			<script>
# 				{
# 					__sveltekit_lebx3m = {
# 						base: new URL("../../..", location).pathname.slice(0, -1)
# 					};
#
# 					const element = document.currentScript.parentElement;
#
# 					const data = [null,{"type":"data","data":{hasThemeSwitchEducationCookie:false,serviceConfig:{finance:{host:"query1.finance.yahoo.com",serverKey:"finance",timeout:3000},financeProd:{host:"query1.finance.yahoo.com",serverKey:"financeProd",timeout:3000},financeStage:{host:"iquery-stage.finance.yahoo.com",serverKey:"financeStage",timeout:3000},preferences:{host:"graviton-home-gateway.media.yahoo.com",serverKey:"preferences",timeout:3000},community:{host:"yfc-server-query.finance.yahoo.com",protocol:"https:",pathname:""},communityMedia:{host:"yfc-media.finance.yahoo.com",protocol:"https:",pathname:""},liveblog:{host:"finance.yahoo.com",pathname:"/caas/content/article/loadMoreBlogPosts",protocol:"https:"},syimg:{host:"s.yimg.com",protocol:"https:",pathname:"/"},timeout:3000,ypfGateway:{host:"ypf-gateway-stage.finance.yahoo.com",protocol:"https:",pathname:""}},session:{consent:{allowContentPersonalization:true,allowCrossDeviceMapping:true,allowFirstPartyAds:true,allowSellPersonalInfo:true,canEmbedThirdPartyContent:true,canSell:true,consentedVendors:["acast","brightcove","dailymotion","facebook","flourish","giphy","instagram","nbcuniversal","playbuzz","scribblelive","soundcloud","tiktok","vimeo","twitter","youtube","masque"]},authed:"0",ynet:"0",ssl:"1",spdy:"0",ytee:"0",mode:"normal",tpConsent:true,site:"finance",adblock:"0",bucket:"",colo:"ir2",device:"desktop",bot:"0",browser:"chrome",app:"unknown",ecma:"modern",environment:"prod",gdpr:false,lang:"en-US",dir:"ltr",intl:"us",network:"mobile",os:"windows nt",partner:"none",region:"US",time:1742337352446,tz:"Africa/Casablanca",usercountry:"MA",rmp:"0",webview:"0",feature:["disableInterstitialUpsells","disableServiceRewrite","disableBack2Classic","disableYPFTaxArticleDisclosure","enable1PVideoTranscript","enableAdRefresh20s","enableAnalystRatings","enableAPIRedisCaching","enableArticleCSN","enableChartbeat","enableChatSupport","enableCommunityToPremiumSubs","enableCommunityTrades","enableCompare","enableCompareConvertCurrency","enableConsentAndGTM","enableCrumbRefresh","enableCSN","enableCurrencyConverter","enableDarkMode","enableDockAddToFollowing","enableDockCondensedHeader","enableDockNeoOptoutLink","enableDockPortfolioControl","enableExperimentalDockModules","enableFollow","enableLazyQSP","enableLiveBlogStatus","enableLivePage","enableStreamingNowBar","enableLocalSpotIM","enableMarketsLeafHeatMap","enableMultiQuote","enableNeoAdvancedChart","enableNeoArticle","enableNeoAuthor","enableNeoBasicPFs","enableNeoGreen","enableNeoHouseCalcPage","enableNeoInvestmentIdea","enableNeoMortgageCalcPage","enableNeoPortfolioDetail","enableNeoQSPReportsLeaf","enableNeoResearchReport","enableNeoTopics","enablePersonalFinanceArticleReadMoreAlgo","enablePersonalFinanceNewsletterIntegration","enablePersonalFinanceZillowIntegration","enablePf2SubsSpotlight","enablePfLandingP2","enablePfPremium","enablePfStreaming","enablePinholeScreenshotOGForQuote","enablePlus","enablePortalStockStory","enableQSPChartEarnings","enableQSPChartNewShading","enableQSPChartRangeTooltips","enableQSPEarnings","enableQSPEarningsVsRev","enableQSPHistoryPlusDownload","enableQSPNavIcon","enableQuoteLookup","enableRecentQuotes","enableResearchHub","enableSECFiling","enableSigninBeforeCheckout","enableSmartAssetMsgA","enableStockStoryPfPage","enableStockStoryTimeToBuy","enableStreamOnlyNews","enableSubsFeatureBar","enableTradeNow","enableYPFArticleReadMoreAll","enableOnePortfolioBanner","enableVideoInHero","enableDockQuoteEventsDateRangeSelect","enablePfDetailDockCollapse","enableHoneyLinks","enableCompareFeatures","enableGenericHeatMap","enableQSPIndustryHeatmap","enableStatusBadge"],isDebug:false,isForScreenshot:false,isWebview:false,theme:"auto",pnrID:"",isError:false,areAdsEnabled:true,ccpa:{warning:"",footerSequence:["terms_and_privacy","dashboard"],links:{dashboard:{url:"https://guce.yahoo.com/privacy-dashboard?locale=en-US",label:"Privacy Dashboard",id:"privacy-link-dashboard"},terms_and_privacy:{multiurl:true,label:"$ ...
#
# 					Promise.all([
# 						import("../../../assets/_app/immutable/entry/start.D85jED9C.js"),
# 						import("../../../assets/_app/immutable/entry/app.GDKKYhNb.js")
# 					]).then(([kit, app]) => {
# 						kit.start(app, element, {
# 							node_ids: [0, 2, 24, 149],
# 							data,
# 							form: null,
# 							error: null
# 						});
# 					});
# 				}
# 			</script>
# 		</div>
#         <script src="https://s.yimg.com/aaq/vzm/cs_2.0.0.js" defer></script><script>(function(){window._comscore = window._comscore||[];window._comscore.push({});window.COMSCORE?.purge();})();
#     </script><script src="https://s.yimg.com/uc/sf/0.1.495/js/safe.modern.js" defer></script><script type="module">
#     (function(win) {
#         win.addEventListener && win.addEventListener("DOMContentLoaded", function () {
#             var s = win.document.createElement("script");
#             s.async = true;
#             s.defer = true;
#             s.src = "https://s.yimg.com/cx/pv/perf-vitals_3.5.0.js";
#             win.document.body.appendChild(s);
#         });
#     })(window);</script>
#     </body>
# </html>

# %% [markdown]
# ### Step 2: Parse the HTML content

# %% [markdown]
# <hr>
# <hr>
# <center>
#
# # What is parsing?
# In simple words, parsing refers to the process of analyzing a string of text or a data structure, usually following a set of rules or grammar, to understand its structure and meaning.
# Parsing involves breaking down a piece of text or data into its individual components or elements, and then analyzing those components to extract the desired information or to understand their relationships and meanings.</center>
# <hr>
# <hr>

# %% [markdown]
# Next you will take the raw HTML content of a web page or a string of HTML code which needs to be parsed and transformed into a structured, hierarchical format that can be more easily analyzed and manipulated in Python. This can be done using a Python library called <b>Beautiful Soup</b>.

# %% [markdown]
# ## Parsing the data using the BeautifulSoup library
# * Create a new BeautifulSoup object.
# <br>
# <br>
# <b>Note: </b>To create a BeautifulSoup object in Python, you need to pass two arguments to its constructor:
#
# 1. The HTML or XML content that you want to parse as a string.
# 2. The name of the parser that you want to use to parse the HTML or XML content. This argument is optional, and if you don't specify a parser, BeautifulSoup will use the default HTML parser included with the library.
# here in this lab we are using "html5lib" parser.

# %%
soup = BeautifulSoup(data, 'html.parser')

# %% [markdown]
# ### Step 3: Identify the HTML tags

# %% [markdown]
# As stated above, the web page consists of a table so, we will scrape the content of the HTML web page and convert the table into a data frame.

# %% [markdown]
# You will create an empty data frame using the <b> pd.DataFrame() </b> function with the following columns:
# * "Date"
# * "Open"
# * "High"
# * "Low"
# * "Close"
# * "Volume"

# %%
netflix_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])
#netflix_data=pd.DataFrame(columns=["Date","Open",....])

# %% [markdown]
# <hr>
# <hr>
# <center>
#
# ### Working on HTML table  </center>
# <br>
#
# These are the following tags which are used while creating HTML tables.
#
# * &lt;table&gt;: This tag is a root tag used to define the start and end of the table. All the content of the table is enclosed within these tags.
#
#
# * &lt;tr&gt;: This tag is used to define a table row. Each row of the table is defined within this tag.
#
# * &lt;td&gt;: This tag is used to define a table cell. Each cell of the table is defined within this tag. You can specify the content of the cell between the opening and closing <td> tags.
#
# * &lt;th&gt;: This tag is used to define a header cell in the table. The header cell is used to describe the contents of a column or row. By default, the text inside a <th> tag is bold and centered.
#
# * &lt;tbody&gt;: This is the main content of the table, which is defined using the <tbody> tag. It contains one or more rows of <tr> elements.
#
# <hr>
# <hr>

# %% [markdown]
# ### Step 4: Use a BeautifulSoup method for extracting data

# %% [markdown]
# We will use <b>find()</b> and <b>find_all()</b> methods of the BeautifulSoup object to locate the table body and table row respectively in the HTML.
#    * The <i>find() method </i> will return particular tag content.
#    * The <i>find_all()</i> method returns a list of all matching tags in the HTML.

# %%
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    
    if len(col) < 7:  # Vérifier si la ligne a au moins 7 colonnes
        continue  # Passer à la ligne suivante

    date = col[0].text.strip()
    Open = col[1].text.strip()
    high = col[2].text.strip()
    low = col[3].text.strip()
    close = col[4].text.strip()
    adj_close = col[5].text.strip()
    volume = col[6].text.strip()
    
    netflix_data = pd.concat([
        netflix_data,
        pd.DataFrame({"Date": [date], "Open": [Open], "High": [high], "Low": [low], "Close": [close], "Adj Close": [adj_close], "Volume": [volume]})
    ], ignore_index=True)

# %%
netflix_data
# Out:
#             Date   Open   High    Low  Close       Volume Adj Close
# 0   Mar 18, 2025   9.95  10.04   9.88   9.95   97,348,528      9.95
# 1   Mar 17, 2025   9.74   9.98   9.74   9.92   98,583,100      9.92
# 2   Mar 10, 2025   9.77  10.14   9.46   9.73  736,366,800      9.73
# 3    Mar 3, 2025   9.71   9.96   9.06   9.90  767,036,400      9.90
# 4   Feb 24, 2025   9.31   9.69   9.21   9.55  457,898,900      9.55
# 5   Mar 18, 2025   9.95  10.04   9.88   9.95   97,348,528      9.95
# 6   Mar 17, 2025   9.74   9.98   9.74   9.92   98,583,100      9.92
# 7   Mar 10, 2025   9.77  10.14   9.46   9.73  736,366,800      9.73
# 8    Mar 3, 2025   9.71   9.96   9.06   9.90  767,036,400      9.90
# 9   Feb 24, 2025   9.31   9.69   9.21   9.55  457,898,900      9.55
# 10  Feb 17, 2025   9.32   9.41   9.21   9.28  210,593,000      8.99
# 11  Feb 10, 2025   9.25   9.51   9.10   9.48  320,190,300      9.18
# 12   Feb 3, 2025   9.72  10.32   9.18   9.24  687,945,600      8.95
# 13  Jan 27, 2025  10.11  10.42   9.92  10.08  408,636,400      9.76
# 14  Jan 20, 2025  10.30  10.45   9.97  10.12  229,770,200      9.80
# 15  Jan 13, 2025   9.66  10.21   9.57  10.18  286,690,000      9.86
# 16   Jan 6, 2025  10.06  10.19   9.58   9.65  261,297,000      9.34
# 17  Dec 30, 2024   9.95  10.01   9.53   9.88  245,623,000      9.57
# 18  Dec 23, 2024   9.87  10.20   9.75  10.03  168,552,300      9.71
# 19  Dec 16, 2024  10.07  10.12   9.66   9.88  426,037,000      9.57
# 20   Dec 9, 2024  10.56  10.80  10.28  10.39  237,794,800     10.06
# 21   Dec 2, 2024  11.22  11.25  10.39  10.51  285,108,400     10.18
# 22  Nov 25, 2024  11.30  11.52  11.04  11.13  168,337,500     10.78
# 23  Nov 18, 2024  11.05  11.38  10.61  11.18  305,634,800     10.83
# 24  Nov 11, 2024  11.07  11.32  10.95  11.01  272,379,100     10.66
# 25   Nov 4, 2024  10.23  11.23  10.23  10.97  306,285,900     10.48
# 26  Oct 28, 2024  11.17  11.39  10.18  10.22  418,619,700      9.76
# 27  Oct 21, 2024  11.08  11.33  10.86  11.07  213,798,700     10.58
# 28  Oct 14, 2024  10.71  11.18  10.66  11.10  205,725,800     10.60
# 29   Oct 7, 2024  10.55  10.80  10.38  10.72  196,145,800     10.24
# 30  Sep 30, 2024  10.48  10.82  10.33  10.57  265,424,600     10.10
# 31  Sep 23, 2024  10.84  11.00  10.32  10.78  249,155,300     10.30
# 32  Sep 16, 2024  10.74  11.31  10.69  10.88  263,133,800     10.39
# 33   Sep 9, 2024  10.61  10.79  10.13  10.69  237,074,800     10.21
# 34   Sep 2, 2024  11.08  11.16  10.53  10.58  195,575,000     10.11
# 35  Aug 26, 2024  11.32  11.37  10.98  11.19  223,319,800     10.69
# 36  Aug 19, 2024  10.56  11.28  10.54  11.27  237,976,300     10.77
# 37  Aug 12, 2024  10.10  10.52   9.77  10.51  213,651,700     10.04
# 38   Aug 5, 2024   9.56  10.25   9.49  10.10  418,762,600      9.50
# 39  Jul 29, 2024  11.18  11.18  10.00  10.03  407,702,000      9.44
# 40  Jul 22, 2024  14.02  14.18  11.05  11.19  565,867,100     10.53
# 41  Jul 15, 2024  14.21  14.85  13.96  13.98  309,756,100     13.15
# 42   Jul 8, 2024  12.97  14.21  12.88  14.03  258,385,700     13.20
# 43   Jul 1, 2024  12.56  12.96  12.53  12.84  161,626,700     12.08
# 44  Jun 24, 2024  11.93  12.62  11.92  12.54  253,182,300     11.80
# 45  Jun 17, 2024  11.66  11.97  11.65  11.84  164,663,400     11.14
# 46  Jun 10, 2024  12.13  12.52  11.55  11.71  264,469,600     11.02
# 47   Jun 3, 2024  12.25  12.32  11.82  12.15  201,050,900     11.43
# 48  May 27, 2024  12.11  12.15  11.48  12.13  202,674,900     11.41
# 49  May 20, 2024  12.27  12.33  11.97  12.16  179,658,300     11.44
# 50  May 13, 2024  12.05  12.64  12.05  12.28  217,196,100     11.55
# 51   May 6, 2024  12.54  12.62  11.91  11.99  196,612,000     11.14
# 52  Apr 29, 2024  12.81  12.84  12.13  12.43  269,257,400     11.55
# 53  Apr 22, 2024  12.31  13.18  12.25  12.79  367,982,100     11.89
# 54  Apr 15, 2024  12.74  12.82  11.94  12.14  239,018,200     11.28
# 55   Apr 8, 2024  13.35  13.59  12.50  12.61  207,540,900     11.72
# 56   Apr 1, 2024  13.33  13.95  13.09  13.28  250,740,400     12.34
# 57  Mar 25, 2024  12.92  13.30  12.43  13.28  221,605,900     12.34
# 58  Mar 18, 2024  12.14  13.06  11.98  12.91  225,937,100     12.00

# %% [markdown]
# ### Step 5: Print the extracted data

# %% [markdown]
# We can now print out the data frame using the head() or tail() function.

# %%
netflix_data.head()
# Out:
#            Date  Open   High   Low Close       Volume Adj Close
# 0  Mar 18, 2025  9.95  10.04  9.88  9.95   97,348,528      9.95
# 1  Mar 17, 2025  9.74   9.98  9.74  9.92   98,583,100      9.92
# 2  Mar 10, 2025  9.77  10.14  9.46  9.73  736,366,800      9.73
# 3   Mar 3, 2025  9.71   9.96  9.06  9.90  767,036,400      9.90
# 4  Feb 24, 2025  9.31   9.69  9.21  9.55  457,898,900      9.55

# %% [markdown]
# # Extracting data using `pandas` library

# %% [markdown]
# We can also use the pandas `read_html` function from the pandas library and use the URL for extracting data.

# %% [markdown]
# <center>
#
# ## What is read_html in pandas library?
# `pd.read_html(url)` is a function provided by the pandas library in Python that is used to extract tables from HTML web pages. It takes in a URL as input and returns a list of all the tables found on the web page.
# </center>

# %%
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)

# %% [markdown]
# Or you can convert the BeautifulSoup object to a string.

# %%
read_html_pandas_data = pd.read_html(str(soup))

# %% [markdown]
# Because there is only one table on the page, just take the first table in the returned list.

# %%
netflix_dataframe = read_html_pandas_data[0]

netflix_dataframe.head()
# Out:
#            Date  Open   High   Low Close Close price adjusted for splits.  \
# 0  Mar 18, 2025  9.95  10.04  9.88                                   9.95
# 1  Mar 17, 2025  9.74   9.98  9.74                                   9.92
# 2  Mar 10, 2025  9.77  10.14  9.46                                   9.73
# 3   Mar 3, 2025  9.71   9.96  9.06                                   9.90
# 4  Feb 24, 2025  9.31   9.69  9.21                                   9.55
#
#   Adj Close Adjusted close price adjusted for splits and dividend and/or capital gain distributions.  \
# 0                                               9.95
# 1                                               9.92
# 2                                               9.73
# 3                                               9.90
# 4                                               9.55
#
#       Volume
# 0   97348528
# 1   98583100
# 2  736366800
# 3  767036400
# 4  457898900

# %% [markdown]
# # Exercise: use webscraping to extract stock data

# %% [markdown]
# Use the `requests` library to download the webpage [https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html). Save the text of the response as a variable named `html_data`.

# %%
url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html"

# %%
html_data=requests.get(url).text

# %% [markdown]
# Parse the html data using `beautiful_soup` using html.parser.

# %%
data=BeautifulSoup(html_data,'html.parser')

# %% [markdown]
# <b>Question 1:</b> What is the content of the title attribute?

# %%
title=data.find("title")
print(title)
# Out:
# <title>Amazon.com, Inc. (AMZN) Stock Historical Prices &amp; Data - Yahoo Finance</title>

# %% [markdown]
# Using BeautifulSoup, extract the table with historical share prices and store it into a data frame named `amazon_data`. The data frame should have columns Date, Open, High, Low, Close, Adj Close, and Volume. Fill in each variable with the correct data from the list `col`.

# %%
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all("tr"):
    col = row.find_all("td")
    if len(col) !=7 :
        continue 
    date = col[0]
    Open = col[1]
    high = col[2]
    low = col[3]
    close = col[4]
    adj_close = col[5]
    volume = col[6]

    amazon_data = pd.concat([amazon_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %% [markdown]
# Print out the first five rows of the `amazon_data` data frame you created.

# %%
print(amazon_data.head())
# Out:
#              Date    Open     High     Low   Close         Volume Adj Close
# 0  [Mar 18, 2025]  [9.95]  [10.04]  [9.88]  [9.95]   [97,348,528]    [9.95]
# 1  [Mar 17, 2025]  [9.74]   [9.98]  [9.74]  [9.92]   [98,583,100]    [9.92]
# 2  [Mar 10, 2025]  [9.77]  [10.14]  [9.46]  [9.73]  [736,366,800]    [9.73]
# 3   [Mar 3, 2025]  [9.71]   [9.96]  [9.06]  [9.90]  [767,036,400]    [9.90]
# 4  [Feb 24, 2025]  [9.31]   [9.69]  [9.21]  [9.55]  [457,898,900]    [9.55]

# %% [markdown]
# <b>Question 2:</b> What are the names of the columns in the data frame?

# %%
amazon_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %% [markdown]
# <b>Question 3:</b> What is the `Open` of the last row of the amazon_data data frame?

# %%
amazon_data.tail(1)
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 53  [Mar 18, 2024]  [12.14]  [13.06]  [11.98]  [12.91]  [225,937,100]
#
#    Adj Close
# 53   [12.00]

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# Azim Hirjani<br>
# Akansha yadav

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    |       Change Description              |
# | ----------------- | ------- | ------------- | ------------------------------------- |
# |  02-05-2023       |   1.3   | Akansha yadav | Updated Lab content under maintenance |
# |  2021-06-09       | 1.2     | Lakshmi Holla |   Added URL in question 3             |
# |  2020-11-10       | 1.1     | Malika Singla |   Deleted the Optional part           |
# |  2020-08-27       | 1.0     | Malika Singla |   Added lab to GitLab                 |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
